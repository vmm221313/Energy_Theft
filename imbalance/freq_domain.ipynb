# %%
import pandas as po
import matplotlib.pyplot as plt

# %%
df = po.read_csv('../data/processed/imputation/edtwbi.csv')

# %%
df = df.drop(['num_zeros', 'FLAG'], axis=1)

# %%
df
# Out:
#        2014/1/1  2014/1/2  2014/1/3  2014/1/4  2014/1/5  2014/1/6  2014/1/7  \
# 0      0.003306  0.005092  0.004084  0.002153  0.002118  0.002233  0.002193
# 1      0.002839  0.002636  0.001719  0.000802  0.001172  0.001789  0.001347
# 2      0.001043  0.001152  0.001260  0.000765  0.001356  0.001947  0.001788
# 3      0.003647  0.004900  0.003473  0.002046  0.002234  0.002423  0.002611
# 4      0.004756  0.004716  0.004660  0.002529  0.002707  0.003427  0.002706
# ...         ...       ...       ...       ...       ...       ...       ...
# 24267  0.002694  0.002704  0.003149  0.001000  0.001347  0.001487  0.001405
# 24268  0.000648  0.000892  0.000438  0.000416  0.000146  0.000177  0.000132
# 24269  0.000073  0.000077  0.000051  0.000061  0.000089  0.000061  0.000043
# 24270  0.000630  0.001240  0.001197  0.000547  0.000635  0.000717  0.000724
# 24271  0.005606  0.002683  0.006354  0.003392  0.003885  0.004022  0.003971
#
# ...
